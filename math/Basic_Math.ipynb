# %% [markdown]
# # Basic Mathematics
# 1. Exponents and Functions
# 2. Logorithms
# 2. Limits
# 3. Derivatives
# 4. Integrals

# %% [markdown]
# Is the value 62.738 rational or irrational number?
#
# Answer: Rational Number

# %% [markdown]
# Evaluate (10**7)(10**-5)

# %%
print((10**7)*(10**-5))
# Out:
# 100.00000000000001

# %% [markdown]
# ## Summation

# %%
summation = sum(2*i for i in range(1,6)) 
print(summation)
# Out:
# 30

# %%
x=[1,4,6,2] 
n = len(x)
summation = sum(10*x[i] for i in range(0,n)) 
print(summation)
# Out:
# 130

# %%
from sympy import *
i,n = symbols('i n')
# iterate each element i from 1 to n, 
# then multiply and sum
summation = Sum(2*i,(i,1,n))
# specify n as 5,
# iterating the numbers 1 through 5 
up_to_5 = summation.subs(n, 5) 
print(up_to_5.doit()) # 30
# Out:
# 30

# %% [markdown]
# ## Logarithms

# %%
from math import log
exponent = log(1)
print (exponent)
# Out:
# 0.0

# %%
from sympy import *
x = symbols('x')
f=1/x
plot(f)

# %% [markdown]
# ## Exponents and Functions

# %% [markdown]
# ### 2D Plotting

# %%
from sympy import *
x = symbols('x')
f=x**2+1
plot(f)

# %% [markdown]
# ### 3-D Plotting

# %%
from sympy import *
from sympy.plotting import plot3d
x, y = symbols('x y')
f=27*x+3*y 
plot3d(f)

# %% [markdown]
# Assuming no payments are made, how much would a $1000 loan be worth a 5% intrest compounded monthly after 3 years?

# %%
from math import exp
p = 1000
r = 0.05
t = 3.0
n = 12
a = p * (1+ (r/n))**(n*t)
print(a)
# Out:
# 1161.4722313334678

# %% [markdown]
# Assuming no payments are made, how much would a $1000 loan be worth a 5% intrest compounded monthly after 3 years?

# %%
from math import exp
p = 1000 # principal, starting amount r = .20 # interest rate, by year
t = 3.0 # time, number of years
a=p*exp(r*t)
print(a)
# Out:
# 1161.834242728283

# %% [markdown]
# ## Derivatives

# %% [markdown]
# For the function f(x) = 3x2 + 1 what is the slope at x = 3?

# %%
from sympy import *
x = symbols('x')

#function
f = 3*x**2+1

dx_f = diff(f)
print(dx_f)
print(dx_f.subs(x,3))
# Out:
# 6*x
# 18

# %% [markdown]
# # Integrals

# %% [markdown]
# For the function f x = 3x2 + 1 what is the area under the curve for x between 0
# and 2?

# %%
# Declare 'x' to SymPy
x = symbols('x')
#declare function
f=3*x**2+1
# Calculate the integral of the function with respect to x # for the area between x = 0 and 2
area = integrate(f, (x, 0, 2))
print(area)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5k/8cjlwr8528v7x2twvvhbj3080000gn/T/ipykernel_7685/3175083950.py in <module>
#       1 # Declare 'x' to SymPy
# ----> 2 x = symbols('x')
#       3 #declare function
#       4 f=3*x**2+1
#       5 # Calculate the integral of the function with respect to x # for the area between x = 0 and 2
#
# NameError: name 'symbols' is not defined
